# %%
import pandas as pd
import glob
import matplotlib
import numpy as np
# %matplotlib inline
matplotlib.style.use('ggplot')
import matplotlib.pyplot as plt
import os
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.svm import LinearSVC
from sklearn.model_selection import train_test_split

# %%
def import_folder(folder):
    filenames = glob.glob("data/" + folder + "/*.tsd")

    files = [file.split('\\')[1].split('.')[0] for file in filenames]

    signs = pd.DataFrame()
    for filename in files:
        df = pd.read_table('data/' + folder +'/' + filename + '.tsd', header=None)
        label = filename.split('-')[0]
        ID = filename.rsplit('-', 1)[1]
        df['label'] = label
        df['ID'] = int(ID)
        df.columns = ['x_L','y_L','z_L','roll_L','pitch_L','yaw_L','thumb_L','fore_L','middle_L','ring_L','little_L','x_R','y_R','z_R','roll_R','pitch_R','yaw_R','thumb_R','fore_R','middle_R','ring_R','little_R', 'label', 'ID']
        signs = signs.append(df)
        
    return signs

# %%
def temporal_scale(signs):
    IDs = signs['ID'].drop_duplicates().values
    labels = signs['label'].drop_duplicates().values
    signs_new = pd.DataFrame(columns = signs.columns)
    for ID in IDs:
        for sign in labels:

            df = signs[(signs['ID'] == ID) & (signs['label'] == sign)]

            df = df[['x_L', 'y_L', 'z_L', 'roll_L', 'pitch_L', 'yaw_L', 'thumb_L', 'fore_L',
                   'middle_L', 'ring_L', 'little_L', 'x_R', 'y_R', 'z_R', 'roll_R',
                   'pitch_R', 'yaw_R', 'thumb_R', 'fore_R', 'middle_R', 'ring_R',
                   'little_R']]

            df_new = pd.DataFrame(index=np.arange(57), columns = df.columns)

            for column in df:    
                column_resample = np.fft.irfft(np.fft.rfft(df[column]), 57)
                df_new[column] = column_resample

            df_new['label'] = sign
            df_new['ID'] = ID
            df_new['folder'] = folder
            signs_new = signs_new.append(df_new)
            #original = signs_new[['x_L', 'y_L', 'z_L', 'x_R', 'y_R', 'z_R']]
            #scaled = (original - original.min())/(original.max() - original.min())
            #signs_new[['x_L', 'y_L', 'z_L', 'x_R', 'y_R', 'z_R']] = scaled
    return signs_new

# %%
root='data'
signs_all = pd.DataFrame()
signs_all_ts = pd.DataFrame()
dirlist = [ item for item in os.listdir(root) if os.path.isdir(os.path.join(root, item)) ]
for folder in dirlist:
    print(folder)
    signs = import_folder(folder)
    signs_ts = temporal_scale(signs)
    signs_all = signs_all.append(signs)
    signs_all_ts = signs_all_ts.append(signs_ts)
# Out:
# tctodd1
# tctodd2
# tctodd3
# tctodd4
# tctodd5
# tctodd6
# tctodd7
# tctodd8
# tctodd9

# %%
def flatten(df):
    df2 = df
    df['frame'] = df.index + 1
    var = ['x_L', 'y_L', 'z_L', 'roll_L', 'pitch_L', 'yaw_L', 'thumb_L', 'fore_L',
                   'middle_L', 'ring_L', 'little_L', 'x_R', 'y_R', 'z_R', 'roll_R',
                   'pitch_R', 'yaw_R', 'thumb_R', 'fore_R', 'middle_R', 'ring_R',
                   'little_R']
    df = df[['x_L', 'y_L', 'z_L', 'roll_L', 'pitch_L', 'yaw_L', 'thumb_L', 'fore_L',
                   'middle_L', 'ring_L', 'little_L', 'x_R', 'y_R', 'z_R', 'roll_R',
                   'pitch_R', 'yaw_R', 'thumb_R', 'fore_R', 'middle_R', 'ring_R',
                   'little_R', 'label', 'frame']]
    df = df.pivot(columns = 'frame', index = 'label').reset_index()
    df.columns = [[str(e[0]) + str(e[1]) for e in df.columns.values.tolist()]]
    df['ID'] = df2['ID']
    df['folder'] = df2['folder']
    del df2
    return df

# %%
IDs = signs['ID'].drop_duplicates().values
labels = signs['label'].drop_duplicates().values

signs_flat = pd.DataFrame()
for folder in dirlist:
    for ID in IDs:
        for sign in labels:
            print(ID, sign, folder)
            df = signs_all_ts[(signs_all_ts['ID'] == ID) & (signs_all_ts['label'] == sign) & (signs_all_ts['folder'] == folder)]
            signs_flat = signs_flat.append(flatten(df))
# Out:
# 1 alive tctodd1
# 1 all tctodd1
# 1 answer tctodd1
# C:\Users\anura\Anaconda3\lib\site-packages\ipykernel\__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
# 1 boy tctodd1
# 1 building tctodd1
# 1 buy tctodd1
# 1 change_mind_ tctodd1
# 1 cold tctodd1
# 1 come tctodd1
# 1 computer_PC_ tctodd1
# 1 cost tctodd1
# 1 crazy tctodd1
# 1 danger tctodd1
# 1 deaf tctodd1
# 1 different tctodd1
# 1 draw tctodd1
# 1 drink tctodd1
# 1 eat tctodd1
# 1 exit tctodd1
# 1 flash tctodd1
# 1 forget tctodd1
# 1 girl tctodd1
# 1 give tctodd1
# 1 glove tctodd1
# 1 go tctodd1
# 1 God tctodd1
# 1 happy tctodd1
# 1 head tctodd1
# 1 hear tctodd1
# 1 hello tctodd1
# 1 his_hers tctodd1
# 1 hot tctodd1
# 1 how tctodd1
# 1 hurry tctodd1
# 1 hurt tctodd1
# 1 I tctodd1
# 1 innocent tctodd1
# 1 is_true_ tctodd1
# 1 joke tctodd1
# 1 juice tctodd1
# 1 know tctodd1
# 1 later tctodd1
# 1 lose tctodd1
# 1 love tctodd1
# 1 make tctodd1
# 1 man tctodd1
# 1 maybe tctodd1
# 1 mine tctodd1
# 1 money tctodd1
# 1 more tctodd1
# 1 name tctodd1
# 1 no tctodd1
# 1 Norway tctodd1
# 1 not tctodd1
# 1 paper tctodd1
# 1 pen tctodd1
# 1 please tctodd1
# 1 polite tctodd1
# 1 question tctodd1
# 1 read tctodd1
# 1 ready tctodd1
# 1 research tctodd1
# 1 responsible tctodd1
# 1 right tctodd1
# 1 sad tctodd1
# 1 same tctodd1
# 1 science tctodd1
# 1 share tctodd1
# 1 shop tctodd1
# 1 soon tctodd1
# 1 sorry tctodd1
# 1 spend tctodd1
# 1 stubborn tctodd1
# 1 surprise tctodd1
# 1 take tctodd1
# 1 temper tctodd1
# 1 thank tctodd1
# 1 think tctodd1
# 1 tray tctodd1
# 1 us tctodd1
# 1 voluntary tctodd1
# 1 wait_notyet_ tctodd1
# 1 what tctodd1
# 1 when tctodd1
# 1 where tctodd1
# 1 which tctodd1
# 1 who tctodd1
# 1 why tctodd1
# 1 wild tctodd1
# 1 will tctodd1
# 1 write tctodd1
# 1 wrong tctodd1
# 1 yes tctodd1
# 1 you tctodd1
# 1 zero tctodd1
# 2 alive tctodd1
# 2 all tctodd1
# 2 answer tctodd1
# 2 boy tctodd1
# 2 building tctodd1
# 2 buy tctodd1
# 2 change_mind_ tctodd1
# 2 cold tctodd1
# 2 come tctodd1
# 2 computer_PC_ tctodd1
# 2 cost tctodd1
# 2 crazy tctodd1
# 2 danger tctodd1
# 2 deaf tctodd1
# 2 different tctodd1
# 2 draw tctodd1
# 2 drink tctodd1
# 2 eat tctodd1
# 2 exit tctodd1
# 2 flash tctodd1
# 2 forget tctodd1
# 2 girl tctodd1
# 2 give tctodd1
# 2 glove tctodd1
# 2 go tctodd1
# 2 God tctodd1
# 2 happy tctodd1
# 2 head tctodd1
# 2 hear tctodd1
# 2 hello tctodd1
# 2 his_hers tctodd1
# 2 hot tctodd1
# 2 how tctodd1
# 2 hurry tctodd1
# 2 hurt tctodd1
# 2 I tctodd1
# 2 innocent tctodd1
# 2 is_true_ tctodd1
# 2 joke tctodd1
# 2 juice tctodd1
# 2 know tctodd1
# 2 later tctodd1
# 2 lose tctodd1
# 2 love tctodd1
# 2 make tctodd1
# 2 man tctodd1
# 2 maybe tctodd1
# 2 mine tctodd1
# 2 money tctodd1
# 2 more tctodd1
# 2 name tctodd1
# 2 no tctodd1
# 2 Norway tctodd1
# 2 not tctodd1
# 2 paper tctodd1
# 2 pen tctodd1
# 2 please tctodd1
# 2 polite tctodd1
# 2 question tctodd1
# 2 read tctodd1
# 2 ready tctodd1
# 2 research tctodd1
# 2 responsible tctodd1
# 2 right tctodd1
# 2 sad tctodd1
# 2 same tctodd1
# 2 science tctodd1
# 2 share tctodd1
# 2 shop tctodd1
# 2 soon tctodd1
# 2 sorry tctodd1
# 2 spend tctodd1
# 2 stubborn tctodd1
# 2 surprise tctodd1
# 2 take tctodd1
# 2 temper tctodd1
# 2 thank tctodd1
# 2 think tctodd1
# 2 tray tctodd1
# 2 us tctodd1
# 2 voluntary tctodd1
# 2 wait_notyet_ tctodd1
# 2 what tctodd1
# 2 when tctodd1
# 2 where tctodd1
# 2 which tctodd1
# 2 who tctodd1
# 2 why tctodd1
# 2 wild tctodd1
# 2 will tctodd1
# 2 write tctodd1
# 2 wrong tctodd1
# 2 yes tctodd1
# 2 you tctodd1
# 2 zero tctodd1
# 3 alive tctodd1
# 3 all tctodd1
# 3 answer tctodd1
# 3 boy tctodd1
# 3 building tctodd1
# 3 buy tctodd1
# 3 change_mind_ tctodd1
# 3 cold tctodd1
# 3 come tctodd1
# 3 computer_PC_ tctodd1
# 3 cost tctodd1
# 3 crazy tctodd1
# 3 danger tctodd1
# 3 deaf tctodd1
# 3 different tctodd1
# 3 draw tctodd1
# 3 drink tctodd1
# 3 eat tctodd1
# 3 exit tctodd1
# 3 flash tctodd1
# 3 forget tctodd1
# 3 girl tctodd1
# 3 give tctodd1
# 3 glove tctodd1
# 3 go tctodd1
# 3 God tctodd1
# 3 happy tctodd1
# 3 head tctodd1
# 3 hear tctodd1
# 3 hello tctodd1
# 3 his_hers tctodd1
# 3 hot tctodd1
# 3 how tctodd1
# 3 hurry tctodd1
# 3 hurt tctodd1
# 3 I tctodd1
# 3 innocent tctodd1
# 3 is_true_ tctodd1
# 3 joke tctodd1
# 3 juice tctodd1
# 3 know tctodd1
# 3 later tctodd1
# 3 lose tctodd1
# 3 love tctodd1
# 3 make tctodd1
# 3 man tctodd1
# 3 maybe tctodd1
# 3 mine tctodd1
# 3 money tctodd1
# 3 more tctodd1
# 3 name tctodd1
# 3 no tctodd1
# 3 Norway tctodd1
# 3 not tctodd1
# 3 paper tctodd1
# 3 pen tctodd1
# 3 please tctodd1
# 3 polite tctodd1
# 3 question tctodd1
# 3 read tctodd1
# 3 ready tctodd1
# 3 research tctodd1
# 3 responsible tctodd1
# 3 right tctodd1
# 3 sad tctodd1
# 3 same tctodd1
# 3 science tctodd1
# 3 share tctodd1
# 3 shop tctodd1
# 3 soon tctodd1
# 3 sorry tctodd1
# 3 spend tctodd1
# 3 stubborn tctodd1
# 3 surprise tctodd1
# 3 take tctodd1
# 3 temper tctodd1
# 3 thank tctodd1
# 3 think tctodd1
# 3 tray tctodd1
# 3 us tctodd1
# 3 voluntary tctodd1
# 3 wait_notyet_ tctodd1
# 3 what tctodd1
# 3 when tctodd1
# 3 where tctodd1
# 3 which tctodd1
# 3 who tctodd1
# 3 why tctodd1
# 3 wild tctodd1
# 3 will tctodd1
# 3 write tctodd1
# 3 wrong tctodd1
# 3 yes tctodd1
# 3 you tctodd1
# 3 zero tctodd1
# 1 alive tctodd2
# 1 all tctodd2
# 1 answer tctodd2
# 1 boy tctodd2
# 1 building tctodd2
# 1 buy tctodd2
# 1 change_mind_ tctodd2
# 1 cold tctodd2
# 1 come tctodd2
# 1 computer_PC_ tctodd2
# 1 cost tctodd2
# 1 crazy tctodd2
# 1 danger tctodd2
# 1 deaf tctodd2
# 1 different tctodd2
# 1 draw tctodd2
# 1 drink tctodd2
# 1 eat tctodd2
# 1 exit tctodd2
# 1 flash tctodd2
# 1 forget tctodd2
# 1 girl tctodd2
# 1 give tctodd2
# 1 glove tctodd2
# 1 go tctodd2
# 1 God tctodd2
# 1 happy tctodd2
# 1 head tctodd2
# 1 hear tctodd2
# 1 hello tctodd2
# 1 his_hers tctodd2
# 1 hot tctodd2
# 1 how tctodd2
# 1 hurry tctodd2
# 1 hurt tctodd2
# 1 I tctodd2
# 1 innocent tctodd2
# 1 is_true_ tctodd2
# 1 joke tctodd2
# 1 juice tctodd2
# 1 know tctodd2
# 1 later tctodd2
# 1 lose tctodd2
# 1 love tctodd2
# 1 make tctodd2
# 1 man tctodd2
# 1 maybe tctodd2
# 1 mine tctodd2
# 1 money tctodd2
# 1 more tctodd2
# 1 name tctodd2
# 1 no tctodd2
# 1 Norway tctodd2
# 1 not tctodd2
# 1 paper tctodd2
# 1 pen tctodd2
# 1 please tctodd2
# 1 polite tctodd2
# 1 question tctodd2
# 1 read tctodd2
# 1 ready tctodd2
# 1 research tctodd2
# 1 responsible tctodd2
# 1 right tctodd2
# 1 sad tctodd2
# 1 same tctodd2
# 1 science tctodd2
# 1 share tctodd2
# 1 shop tctodd2
# 1 soon tctodd2
# 1 sorry tctodd2
# 1 spend tctodd2
# 1 stubborn tctodd2
# 1 surprise tctodd2
# 1 take tctodd2
# 1 temper tctodd2
# 1 thank tctodd2
# 1 think tctodd2
# 1 tray tctodd2
# 1 us tctodd2
# 1 voluntary tctodd2
# 1 wait_notyet_ tctodd2
# 1 what tctodd2
# 1 when tctodd2
# 1 where tctodd2
# 1 which tctodd2
# 1 who tctodd2
# 1 why tctodd2
# 1 wild tctodd2
# 1 will tctodd2
# 1 write tctodd2
# 1 wrong tctodd2
# 1 yes tctodd2
# 1 you tctodd2
# 1 zero tctodd2
# 2 alive tctodd2
# 2 all tctodd2
# 2 answer tctodd2
# 2 boy tctodd2
# 2 building tctodd2
# 2 buy tctodd2
# 2 change_mind_ tctodd2
# 2 cold tctodd2
# 2 come tctodd2
# 2 computer_PC_ tctodd2
# 2 cost tctodd2
# 2 crazy tctodd2
# 2 danger tctodd2
# 2 deaf tctodd2
# 2 different tctodd2
# 2 draw tctodd2
# 2 drink tctodd2
# 2 eat tctodd2
# 2 exit tctodd2
# 2 flash tctodd2
# 2 forget tctodd2
# 2 girl tctodd2
# 2 give tctodd2
# 2 glove tctodd2
# 2 go tctodd2
# 2 God tctodd2
# 2 happy tctodd2
# 2 head tctodd2
# 2 hear tctodd2
# 2 hello tctodd2
# 2 his_hers tctodd2
# 2 hot tctodd2
# 2 how tctodd2
# 2 hurry tctodd2
# 2 hurt tctodd2
# 2 I tctodd2
# 2 innocent tctodd2
# 2 is_true_ tctodd2
# 2 joke tctodd2
# 2 juice tctodd2
# 2 know tctodd2
# 2 later tctodd2
# 2 lose tctodd2
# 2 love tctodd2
# 2 make tctodd2
# 2 man tctodd2
# 2 maybe tctodd2
# 2 mine tctodd2
# 2 money tctodd2
# 2 more tctodd2
# 2 name tctodd2
# 2 no tctodd2
# 2 Norway tctodd2
# 2 not tctodd2
# 2 paper tctodd2
# 2 pen tctodd2
# 2 please tctodd2
# 2 polite tctodd2
# 2 question tctodd2
# 2 read tctodd2
# 2 ready tctodd2
# 2 research tctodd2
# 2 responsible tctodd2
# 2 right tctodd2
# 2 sad tctodd2
# 2 same tctodd2
# 2 science tctodd2
# 2 share tctodd2
# 2 shop tctodd2
# 2 soon tctodd2
# 2 sorry tctodd2
# 2 spend tctodd2
# 2 stubborn tctodd2
# 2 surprise tctodd2
# 2 take tctodd2
# 2 temper tctodd2
# 2 thank tctodd2
# 2 think tctodd2
# 2 tray tctodd2
# 2 us tctodd2
# 2 voluntary tctodd2
# 2 wait_notyet_ tctodd2
# 2 what tctodd2
# 2 when tctodd2
# 2 where tctodd2
# 2 which tctodd2
# 2 who tctodd2
# 2 why tctodd2
# 2 wild tctodd2
# 2 will tctodd2
# 2 write tctodd2
# 2 wrong tctodd2
# 2 yes tctodd2
# 2 you tctodd2
# 2 zero tctodd2
# 3 alive tctodd2
# 3 all tctodd2
# 3 answer tctodd2
# 3 boy tctodd2
# 3 building tctodd2
# 3 buy tctodd2
# 3 change_mind_ tctodd2
# 3 cold tctodd2
# 3 come tctodd2
# 3 computer_PC_ tctodd2
# 3 cost tctodd2
# 3 crazy tctodd2
# 3 danger tctodd2
# 3 deaf tctodd2
# 3 different tctodd2
# 3 draw tctodd2
# 3 drink tctodd2
# 3 eat tctodd2
# 3 exit tctodd2
# 3 flash tctodd2
# 3 forget tctodd2
# 3 girl tctodd2
# 3 give tctodd2
# 3 glove tctodd2
# 3 go tctodd2
# 3 God tctodd2
# 3 happy tctodd2
# 3 head tctodd2
# 3 hear tctodd2
# 3 hello tctodd2
# 3 his_hers tctodd2
# 3 hot tctodd2
# 3 how tctodd2
# 3 hurry tctodd2
# 3 hurt tctodd2
# 3 I tctodd2
# 3 innocent tctodd2
# 3 is_true_ tctodd2
# 3 joke tctodd2
# 3 juice tctodd2
# 3 know tctodd2
# 3 later tctodd2
# 3 lose tctodd2
# 3 love tctodd2
# 3 make tctodd2
# 3 man tctodd2
# 3 maybe tctodd2
# 3 mine tctodd2
# 3 money tctodd2
# 3 more tctodd2
# 3 name tctodd2
# 3 no tctodd2
# 3 Norway tctodd2
# 3 not tctodd2
# 3 paper tctodd2
# 3 pen tctodd2
# 3 please tctodd2
# 3 polite tctodd2
# 3 question tctodd2
# 3 read tctodd2
# 3 ready tctodd2
# 3 research tctodd2
# 3 responsible tctodd2
# 3 right tctodd2
# 3 sad tctodd2
# 3 same tctodd2
# 3 science tctodd2
# 3 share tctodd2
# 3 shop tctodd2
# 3 soon tctodd2
# 3 sorry tctodd2
# 3 spend tctodd2
# 3 stubborn tctodd2
# 3 surprise tctodd2
# 3 take tctodd2
# 3 temper tctodd2
# 3 thank tctodd2
# 3 think tctodd2
# 3 tray tctodd2
# 3 us tctodd2
# 3 voluntary tctodd2
# 3 wait_notyet_ tctodd2
# 3 what tctodd2
# 3 when tctodd2
# 3 where tctodd2
# 3 which tctodd2
# 3 who tctodd2
# 3 why tctodd2
# 3 wild tctodd2
# 3 will tctodd2
# 3 write tctodd2
# 3 wrong tctodd2
# 3 yes tctodd2
# 3 you tctodd2
# 3 zero tctodd2
# 1 alive tctodd3
# 1 all tctodd3
# 1 answer tctodd3
# 1 boy tctodd3
# 1 building tctodd3
# 1 buy tctodd3
# 1 change_mind_ tctodd3
# 1 cold tctodd3
# 1 come tctodd3
# 1 computer_PC_ tctodd3
# 1 cost tctodd3
# 1 crazy tctodd3
# 1 danger tctodd3
# 1 deaf tctodd3
# 1 different tctodd3
# 1 draw tctodd3
# 1 drink tctodd3
# 1 eat tctodd3
# 1 exit tctodd3
# 1 flash tctodd3
# 1 forget tctodd3
# 1 girl tctodd3
# 1 give tctodd3
# 1 glove tctodd3
# 1 go tctodd3
# 1 God tctodd3
# 1 happy tctodd3
# 1 head tctodd3
# 1 hear tctodd3
# 1 hello tctodd3
# 1 his_hers tctodd3
# 1 hot tctodd3
# 1 how tctodd3
# 1 hurry tctodd3
# 1 hurt tctodd3
# 1 I tctodd3
# 1 innocent tctodd3
# 1 is_true_ tctodd3
# 1 joke tctodd3
# 1 juice tctodd3
# 1 know tctodd3
# 1 later tctodd3
# 1 lose tctodd3
# 1 love tctodd3
# 1 make tctodd3
# 1 man tctodd3
# 1 maybe tctodd3
# 1 mine tctodd3
# 1 money tctodd3
# 1 more tctodd3
# 1 name tctodd3
# 1 no tctodd3
# 1 Norway tctodd3
# 1 not tctodd3
# 1 paper tctodd3
# 1 pen tctodd3
# 1 please tctodd3
# 1 polite tctodd3
# 1 question tctodd3
# 1 read tctodd3
# 1 ready tctodd3
# 1 research tctodd3
# 1 responsible tctodd3
# 1 right tctodd3
# 1 sad tctodd3
# 1 same tctodd3
# 1 science tctodd3
# 1 share tctodd3
# 1 shop tctodd3
# 1 soon tctodd3
# 1 sorry tctodd3
# 1 spend tctodd3
# 1 stubborn tctodd3
# 1 surprise tctodd3
# 1 take tctodd3
# 1 temper tctodd3
# 1 thank tctodd3
# 1 think tctodd3
# 1 tray tctodd3
# 1 us tctodd3
# 1 voluntary tctodd3
# 1 wait_notyet_ tctodd3
# 1 what tctodd3
# 1 when tctodd3
# 1 where tctodd3
# 1 which tctodd3
# 1 who tctodd3
# 1 why tctodd3
# 1 wild tctodd3
# 1 will tctodd3
# 1 write tctodd3
# 1 wrong tctodd3
# 1 yes tctodd3
# 1 you tctodd3
# 1 zero tctodd3
# 2 alive tctodd3
# 2 all tctodd3
# 2 answer tctodd3
# 2 boy tctodd3
# 2 building tctodd3
# 2 buy tctodd3
# 2 change_mind_ tctodd3
# 2 cold tctodd3
# 2 come tctodd3
# 2 computer_PC_ tctodd3
# 2 cost tctodd3
# 2 crazy tctodd3
# 2 danger tctodd3
# 2 deaf tctodd3
# 2 different tctodd3
# 2 draw tctodd3
# 2 drink tctodd3
# 2 eat tctodd3
# 2 exit tctodd3
# 2 flash tctodd3
# 2 forget tctodd3
# 2 girl tctodd3
# 2 give tctodd3
# 2 glove tctodd3
# 2 go tctodd3
# 2 God tctodd3
# 2 happy tctodd3
# 2 head tctodd3
# 2 hear tctodd3
# 2 hello tctodd3
# 2 his_hers tctodd3
# 2 hot tctodd3
# 2 how tctodd3
# 2 hurry tctodd3
# 2 hurt tctodd3
# 2 I tctodd3
# 2 innocent tctodd3
# 2 is_true_ tctodd3
# 2 joke tctodd3
# 2 juice tctodd3
# 2 know tctodd3
# 2 later tctodd3
# 2 lose tctodd3
# 2 love tctodd3
# 2 make tctodd3
# 2 man tctodd3
# 2 maybe tctodd3
# 2 mine tctodd3
# 2 money tctodd3
# 2 more tctodd3
# 2 name tctodd3
# 2 no tctodd3
# 2 Norway tctodd3
# 2 not tctodd3
# 2 paper tctodd3
# 2 pen tctodd3
# 2 please tctodd3
# 2 polite tctodd3
# 2 question tctodd3
# 2 read tctodd3
# 2 ready tctodd3
# 2 research tctodd3
# 2 responsible tctodd3
# 2 right tctodd3
# 2 sad tctodd3
# 2 same tctodd3
# 2 science tctodd3
# 2 share tctodd3
# 2 shop tctodd3
# 2 soon tctodd3
# 2 sorry tctodd3
# 2 spend tctodd3
# 2 stubborn tctodd3
# 2 surprise tctodd3
# 2 take tctodd3
# 2 temper tctodd3
# 2 thank tctodd3
# 2 think tctodd3
# 2 tray tctodd3
# 2 us tctodd3
# 2 voluntary tctodd3
# 2 wait_notyet_ tctodd3
# 2 what tctodd3
# 2 when tctodd3
# 2 where tctodd3
# 2 which tctodd3
# 2 who tctodd3
# 2 why tctodd3
# 2 wild tctodd3
# 2 will tctodd3
# 2 write tctodd3
# 2 wrong tctodd3
# 2 yes tctodd3
# 2 you tctodd3
# 2 zero tctodd3
# 3 alive tctodd3
# 3 all tctodd3
# 3 answer tctodd3
# 3 boy tctodd3
# 3 building tctodd3
# 3 buy tctodd3
# 3 change_mind_ tctodd3
# 3 cold tctodd3
# 3 come tctodd3
# 3 computer_PC_ tctodd3
# 3 cost tctodd3
# 3 crazy tctodd3
# 3 danger tctodd3
# 3 deaf tctodd3
# 3 different tctodd3
# 3 draw tctodd3
# 3 drink tctodd3
# 3 eat tctodd3
# 3 exit tctodd3
# 3 flash tctodd3
# 3 forget tctodd3
# 3 girl tctodd3
# 3 give tctodd3
# 3 glove tctodd3
# 3 go tctodd3
# 3 God tctodd3
# 3 happy tctodd3
# 3 head tctodd3
# 3 hear tctodd3
# 3 hello tctodd3
# 3 his_hers tctodd3
# 3 hot tctodd3
# 3 how tctodd3
# 3 hurry tctodd3
# 3 hurt tctodd3
# 3 I tctodd3
# 3 innocent tctodd3
# 3 is_true_ tctodd3
# 3 joke tctodd3
# 3 juice tctodd3
# 3 know tctodd3
# 3 later tctodd3
# 3 lose tctodd3
# 3 love tctodd3
# 3 make tctodd3
# 3 man tctodd3
# 3 maybe tctodd3
# 3 mine tctodd3
# 3 money tctodd3
# 3 more tctodd3
# 3 name tctodd3
# 3 no tctodd3
# 3 Norway tctodd3
# 3 not tctodd3
# 3 paper tctodd3
# 3 pen tctodd3
# 3 please tctodd3
# 3 polite tctodd3
# 3 question tctodd3
# 3 read tctodd3
# 3 ready tctodd3
# 3 research tctodd3
# 3 responsible tctodd3
# 3 right tctodd3
# 3 sad tctodd3
# 3 same tctodd3
# 3 science tctodd3
# 3 share tctodd3
# 3 shop tctodd3
# 3 soon tctodd3
# 3 sorry tctodd3
# 3 spend tctodd3
# 3 stubborn tctodd3
# 3 surprise tctodd3
# 3 take tctodd3
# 3 temper tctodd3
# 3 thank tctodd3
# 3 think tctodd3
# 3 tray tctodd3
# 3 us tctodd3
# 3 voluntary tctodd3
# 3 wait_notyet_ tctodd3
# 3 what tctodd3
# 3 when tctodd3
# 3 where tctodd3
# 3 which tctodd3
# 3 who tctodd3
# 3 why tctodd3
# 3 wild tctodd3
# 3 will tctodd3
# 3 write tctodd3
# 3 wrong tctodd3
# 3 yes tctodd3
# 3 you tctodd3
# 3 zero tctodd3
# 1 alive tctodd4
# 1 all tctodd4
# 1 answer tctodd4
# 1 boy tctodd4
# 1 building tctodd4
# 1 buy tctodd4
# 1 change_mind_ tctodd4
# 1 cold tctodd4
# 1 come tctodd4
# 1 computer_PC_ tctodd4
# 1 cost tctodd4
# 1 crazy tctodd4
# 1 danger tctodd4
# 1 deaf tctodd4
# 1 different tctodd4
# 1 draw tctodd4
# 1 drink tctodd4
# 1 eat tctodd4
# 1 exit tctodd4
# 1 flash tctodd4
# 1 forget tctodd4
# 1 girl tctodd4
# 1 give tctodd4
# 1 glove tctodd4
# 1 go tctodd4
# 1 God tctodd4
# 1 happy tctodd4
# 1 head tctodd4
# 1 hear tctodd4
# 1 hello tctodd4
# 1 his_hers tctodd4
# 1 hot tctodd4
# 1 how tctodd4
# 1 hurry tctodd4
# 1 hurt tctodd4
# 1 I tctodd4
# 1 innocent tctodd4
# 1 is_true_ tctodd4
# 1 joke tctodd4
# 1 juice tctodd4
# 1 know tctodd4
# 1 later tctodd4
# 1 lose tctodd4
# 1 love tctodd4
# 1 make tctodd4
# 1 man tctodd4
# 1 maybe tctodd4
# 1 mine tctodd4
# 1 money tctodd4
# 1 more tctodd4
# 1 name tctodd4
# 1 no tctodd4
# 1 Norway tctodd4
# 1 not tctodd4
# 1 paper tctodd4
# 1 pen tctodd4
# 1 please tctodd4
# 1 polite tctodd4
# 1 question tctodd4
# 1 read tctodd4
# 1 ready tctodd4
# 1 research tctodd4
# 1 responsible tctodd4
# 1 right tctodd4
# 1 sad tctodd4
# 1 same tctodd4
# 1 science tctodd4
# 1 share tctodd4
# 1 shop tctodd4
# 1 soon tctodd4
# 1 sorry tctodd4
# 1 spend tctodd4
# 1 stubborn tctodd4
# 1 surprise tctodd4
# 1 take tctodd4
# 1 temper tctodd4
# 1 thank tctodd4
# 1 think tctodd4
# 1 tray tctodd4
# 1 us tctodd4
# 1 voluntary tctodd4
# 1 wait_notyet_ tctodd4
# 1 what tctodd4
# 1 when tctodd4
# 1 where tctodd4
# 1 which tctodd4
# 1 who tctodd4
# 1 why tctodd4
# 1 wild tctodd4
# 1 will tctodd4
# 1 write tctodd4
# 1 wrong tctodd4
# 1 yes tctodd4
# 1 you tctodd4
# 1 zero tctodd4
# 2 alive tctodd4
# 2 all tctodd4
# 2 answer tctodd4
# 2 boy tctodd4
# 2 building tctodd4
# 2 buy tctodd4
# 2 change_mind_ tctodd4
# 2 cold tctodd4
# 2 come tctodd4
# 2 computer_PC_ tctodd4
# 2 cost tctodd4
# 2 crazy tctodd4
# 2 danger tctodd4
# 2 deaf tctodd4
# 2 different tctodd4
# 2 draw tctodd4
# 2 drink tctodd4
# 2 eat tctodd4
# 2 exit tctodd4
# 2 flash tctodd4
# 2 forget tctodd4
# 2 girl tctodd4
# 2 give tctodd4
# 2 glove tctodd4
# 2 go tctodd4
# 2 God tctodd4
# 2 happy tctodd4
# 2 head tctodd4
# 2 hear tctodd4
# 2 hello tctodd4
# 2 his_hers tctodd4
# 2 hot tctodd4
# 2 how tctodd4
# 2 hurry tctodd4
# 2 hurt tctodd4
# 2 I tctodd4
# 2 innocent tctodd4
# 2 is_true_ tctodd4
# 2 joke tctodd4
# 2 juice tctodd4
# 2 know tctodd4
# 2 later tctodd4
# 2 lose tctodd4
# 2 love tctodd4
# 2 make tctodd4
# 2 man tctodd4
# 2 maybe tctodd4
# 2 mine tctodd4
# 2 money tctodd4
# 2 more tctodd4
# 2 name tctodd4
# 2 no tctodd4
# 2 Norway tctodd4
# 2 not tctodd4
# 2 paper tctodd4
# 2 pen tctodd4
# 2 please tctodd4
# 2 polite tctodd4
# 2 question tctodd4
# 2 read tctodd4
# 2 ready tctodd4
# 2 research tctodd4
# 2 responsible tctodd4
# 2 right tctodd4
# 2 sad tctodd4
# 2 same tctodd4
# 2 science tctodd4
# 2 share tctodd4
# 2 shop tctodd4
# 2 soon tctodd4
# 2 sorry tctodd4
# 2 spend tctodd4
# 2 stubborn tctodd4
# 2 surprise tctodd4
# 2 take tctodd4
# 2 temper tctodd4
# 2 thank tctodd4
# 2 think tctodd4
# 2 tray tctodd4
# 2 us tctodd4
# 2 voluntary tctodd4
# 2 wait_notyet_ tctodd4
# 2 what tctodd4
# 2 when tctodd4
# 2 where tctodd4
# 2 which tctodd4
# 2 who tctodd4
# 2 why tctodd4
# 2 wild tctodd4
# 2 will tctodd4
# 2 write tctodd4
# 2 wrong tctodd4
# 2 yes tctodd4
# 2 you tctodd4
# 2 zero tctodd4
# 3 alive tctodd4
# 3 all tctodd4
# 3 answer tctodd4
# 3 boy tctodd4
# 3 building tctodd4
# 3 buy tctodd4
# 3 change_mind_ tctodd4
# 3 cold tctodd4
# 3 come tctodd4
# 3 computer_PC_ tctodd4
# 3 cost tctodd4
# 3 crazy tctodd4
# 3 danger tctodd4
# 3 deaf tctodd4
# 3 different tctodd4
# 3 draw tctodd4
# 3 drink tctodd4
# 3 eat tctodd4
# 3 exit tctodd4
# 3 flash tctodd4
# 3 forget tctodd4
# 3 girl tctodd4
# 3 give tctodd4
# 3 glove tctodd4
# 3 go tctodd4
# 3 God tctodd4
# 3 happy tctodd4
# 3 head tctodd4
# 3 hear tctodd4
# 3 hello tctodd4
# 3 his_hers tctodd4
# 3 hot tctodd4
# 3 how tctodd4
# 3 hurry tctodd4
# 3 hurt tctodd4
# 3 I tctodd4
# 3 innocent tctodd4
# 3 is_true_ tctodd4
# 3 joke tctodd4
# 3 juice tctodd4
# 3 know tctodd4
# 3 later tctodd4
# 3 lose tctodd4
# 3 love tctodd4
# 3 make tctodd4
# 3 man tctodd4
# 3 maybe tctodd4
# 3 mine tctodd4
# 3 money tctodd4
# 3 more tctodd4
# 3 name tctodd4
# 3 no tctodd4
# 3 Norway tctodd4
# 3 not tctodd4
# 3 paper tctodd4
# 3 pen tctodd4
# 3 please tctodd4
# 3 polite tctodd4
# 3 question tctodd4
# 3 read tctodd4
# 3 ready tctodd4
# 3 research tctodd4
# 3 responsible tctodd4
# 3 right tctodd4
# 3 sad tctodd4
# 3 same tctodd4
# 3 science tctodd4
# 3 share tctodd4
# 3 shop tctodd4
# 3 soon tctodd4
# 3 sorry tctodd4
# 3 spend tctodd4
# 3 stubborn tctodd4
# 3 surprise tctodd4
# 3 take tctodd4
# 3 temper tctodd4
# 3 thank tctodd4
# 3 think tctodd4
# 3 tray tctodd4
# 3 us tctodd4
# 3 voluntary tctodd4
# 3 wait_notyet_ tctodd4
# 3 what tctodd4
# 3 when tctodd4
# 3 where tctodd4
# 3 which tctodd4
# 3 who tctodd4
# 3 why tctodd4
# 3 wild tctodd4
# 3 will tctodd4
# 3 write tctodd4
# 3 wrong tctodd4
# 3 yes tctodd4
# 3 you tctodd4
# 3 zero tctodd4
# 1 alive tctodd5
# 1 all tctodd5
# 1 answer tctodd5
# 1 boy tctodd5
# 1 building tctodd5
# 1 buy tctodd5
# 1 change_mind_ tctodd5
# 1 cold tctodd5
# 1 come tctodd5
# 1 computer_PC_ tctodd5
# 1 cost tctodd5
# 1 crazy tctodd5
# 1 danger tctodd5
# 1 deaf tctodd5
# 1 different tctodd5
# 1 draw tctodd5
# 1 drink tctodd5
# 1 eat tctodd5
# 1 exit tctodd5
# 1 flash tctodd5
# 1 forget tctodd5
# 1 girl tctodd5
# 1 give tctodd5
# 1 glove tctodd5
# 1 go tctodd5
# 1 God tctodd5
# 1 happy tctodd5
# 1 head tctodd5
# 1 hear tctodd5
# 1 hello tctodd5
# 1 his_hers tctodd5
# 1 hot tctodd5
# 1 how tctodd5
# 1 hurry tctodd5
# 1 hurt tctodd5
# 1 I tctodd5
# 1 innocent tctodd5
# 1 is_true_ tctodd5
# 1 joke tctodd5
# 1 juice tctodd5
# 1 know tctodd5
# 1 later tctodd5
# 1 lose tctodd5
# 1 love tctodd5
# 1 make tctodd5
# 1 man tctodd5
# 1 maybe tctodd5
# 1 mine tctodd5
# 1 money tctodd5
# 1 more tctodd5
# 1 name tctodd5
# 1 no tctodd5
# 1 Norway tctodd5
# 1 not tctodd5
# 1 paper tctodd5
# 1 pen tctodd5
# 1 please tctodd5
# 1 polite tctodd5
# 1 question tctodd5
# 1 read tctodd5
# 1 ready tctodd5
# 1 research tctodd5
# 1 responsible tctodd5
# 1 right tctodd5
# 1 sad tctodd5
# 1 same tctodd5
# 1 science tctodd5
# 1 share tctodd5
# 1 shop tctodd5
# 1 soon tctodd5
# 1 sorry tctodd5
# 1 spend tctodd5
# 1 stubborn tctodd5
# 1 surprise tctodd5
# 1 take tctodd5
# 1 temper tctodd5
# 1 thank tctodd5
# 1 think tctodd5
# 1 tray tctodd5
# 1 us tctodd5
# 1 voluntary tctodd5
# 1 wait_notyet_ tctodd5
# 1 what tctodd5
# 1 when tctodd5
# 1 where tctodd5
# 1 which tctodd5
# 1 who tctodd5
# 1 why tctodd5
# 1 wild tctodd5
# 1 will tctodd5
# 1 write tctodd5
# 1 wrong tctodd5
# 1 yes tctodd5
# 1 you tctodd5
# 1 zero tctodd5
# 2 alive tctodd5
# 2 all tctodd5
# 2 answer tctodd5
# 2 boy tctodd5
# 2 building tctodd5
# 2 buy tctodd5
# 2 change_mind_ tctodd5
# 2 cold tctodd5
# 2 come tctodd5
# 2 computer_PC_ tctodd5
# 2 cost tctodd5
# 2 crazy tctodd5
# 2 danger tctodd5
# 2 deaf tctodd5
# 2 different tctodd5
# 2 draw tctodd5
# 2 drink tctodd5
# 2 eat tctodd5
# 2 exit tctodd5
# 2 flash tctodd5
# 2 forget tctodd5
# 2 girl tctodd5
# 2 give tctodd5
# 2 glove tctodd5
# 2 go tctodd5
# 2 God tctodd5
# 2 happy tctodd5
# 2 head tctodd5
# 2 hear tctodd5
# 2 hello tctodd5
# 2 his_hers tctodd5
# 2 hot tctodd5
# 2 how tctodd5
# 2 hurry tctodd5
# 2 hurt tctodd5
# 2 I tctodd5
# 2 innocent tctodd5
# 2 is_true_ tctodd5
# 2 joke tctodd5
# 2 juice tctodd5
# 2 know tctodd5
# 2 later tctodd5
# 2 lose tctodd5
# 2 love tctodd5
# 2 make tctodd5
# 2 man tctodd5
# 2 maybe tctodd5
# 2 mine tctodd5
# 2 money tctodd5
# 2 more tctodd5
# 2 name tctodd5
# 2 no tctodd5
# 2 Norway tctodd5
# 2 not tctodd5
# 2 paper tctodd5
# 2 pen tctodd5
# 2 please tctodd5
# 2 polite tctodd5
# 2 question tctodd5
# 2 read tctodd5
# 2 ready tctodd5
# 2 research tctodd5
# 2 responsible tctodd5
# 2 right tctodd5
# 2 sad tctodd5
# 2 same tctodd5
# 2 science tctodd5
# 2 share tctodd5
# 2 shop tctodd5
# 2 soon tctodd5
# 2 sorry tctodd5
# 2 spend tctodd5
# 2 stubborn tctodd5
# 2 surprise tctodd5
# 2 take tctodd5
# 2 temper tctodd5
# 2 thank tctodd5
# 2 think tctodd5
# 2 tray tctodd5
# 2 us tctodd5
# 2 voluntary tctodd5
# 2 wait_notyet_ tctodd5
# 2 what tctodd5
# 2 when tctodd5
# 2 where tctodd5
# 2 which tctodd5
# 2 who tctodd5
# 2 why tctodd5
# 2 wild tctodd5
# 2 will tctodd5
# 2 write tctodd5
# 2 wrong tctodd5
# 2 yes tctodd5
# 2 you tctodd5
# 2 zero tctodd5
# 3 alive tctodd5
# 3 all tctodd5
# 3 answer tctodd5
# 3 boy tctodd5
# 3 building tctodd5
# 3 buy tctodd5
# 3 change_mind_ tctodd5
# 3 cold tctodd5
# 3 come tctodd5
# 3 computer_PC_ tctodd5
# 3 cost tctodd5
# 3 crazy tctodd5
# 3 danger tctodd5
# 3 deaf tctodd5
# 3 different tctodd5
# 3 draw tctodd5
# 3 drink tctodd5
# 3 eat tctodd5
# 3 exit tctodd5
# 3 flash tctodd5
# 3 forget tctodd5
# 3 girl tctodd5
# 3 give tctodd5
# 3 glove tctodd5
# 3 go tctodd5
# 3 God tctodd5
# 3 happy tctodd5
# 3 head tctodd5
# 3 hear tctodd5
# 3 hello tctodd5
# 3 his_hers tctodd5
# 3 hot tctodd5
# 3 how tctodd5
# 3 hurry tctodd5
# 3 hurt tctodd5
# 3 I tctodd5
# 3 innocent tctodd5
# 3 is_true_ tctodd5
# 3 joke tctodd5
# 3 juice tctodd5
# 3 know tctodd5
# 3 later tctodd5
# 3 lose tctodd5
# 3 love tctodd5
# 3 make tctodd5
# 3 man tctodd5
# 3 maybe tctodd5
# 3 mine tctodd5
# 3 money tctodd5
# 3 more tctodd5
# 3 name tctodd5
# 3 no tctodd5
# 3 Norway tctodd5
# 3 not tctodd5
# 3 paper tctodd5
# 3 pen tctodd5
# 3 please tctodd5
# 3 polite tctodd5
# 3 question tctodd5
# 3 read tctodd5
# 3 ready tctodd5
# 3 research tctodd5
# 3 responsible tctodd5
# 3 right tctodd5
# 3 sad tctodd5
# 3 same tctodd5
# 3 science tctodd5
# 3 share tctodd5
# 3 shop tctodd5
# 3 soon tctodd5
# 3 sorry tctodd5
# 3 spend tctodd5
# 3 stubborn tctodd5
# 3 surprise tctodd5
# 3 take tctodd5
# 3 temper tctodd5
# 3 thank tctodd5
# 3 think tctodd5
# 3 tray tctodd5
# 3 us tctodd5
# 3 voluntary tctodd5
# 3 wait_notyet_ tctodd5
# 3 what tctodd5
# 3 when tctodd5
# 3 where tctodd5
# 3 which tctodd5
# 3 who tctodd5
# 3 why tctodd5
# 3 wild tctodd5
# 3 will tctodd5
# 3 write tctodd5
# 3 wrong tctodd5
# 3 yes tctodd5
# 3 you tctodd5
# 3 zero tctodd5
# 1 alive tctodd6
# 1 all tctodd6
# 1 answer tctodd6
# 1 boy tctodd6
# 1 building tctodd6
# 1 buy tctodd6
# 1 change_mind_ tctodd6
# 1 cold tctodd6
# 1 come tctodd6
# 1 computer_PC_ tctodd6
# 1 cost tctodd6
# 1 crazy tctodd6
# 1 danger tctodd6
# 1 deaf tctodd6
# 1 different tctodd6
# 1 draw tctodd6
# 1 drink tctodd6
# 1 eat tctodd6
# 1 exit tctodd6
# 1 flash tctodd6
# 1 forget tctodd6
# 1 girl tctodd6
# 1 give tctodd6
# 1 glove tctodd6
# 1 go tctodd6
# 1 God tctodd6
# 1 happy tctodd6
# 1 head tctodd6
# 1 hear tctodd6
# 1 hello tctodd6
# 1 his_hers tctodd6
# 1 hot tctodd6
# 1 how tctodd6
# 1 hurry tctodd6
# 1 hurt tctodd6
# 1 I tctodd6
# 1 innocent tctodd6
# 1 is_true_ tctodd6
# 1 joke tctodd6
# 1 juice tctodd6
# 1 know tctodd6
# 1 later tctodd6
# 1 lose tctodd6
# 1 love tctodd6
# 1 make tctodd6
# 1 man tctodd6
# 1 maybe tctodd6
# 1 mine tctodd6
# 1 money tctodd6
# 1 more tctodd6
# 1 name tctodd6
# 1 no tctodd6
# 1 Norway tctodd6
# 1 not tctodd6
# 1 paper tctodd6
# 1 pen tctodd6
# 1 please tctodd6
# 1 polite tctodd6
# 1 question tctodd6
# 1 read tctodd6
# 1 ready tctodd6
# 1 research tctodd6
# 1 responsible tctodd6
# 1 right tctodd6
# 1 sad tctodd6
# 1 same tctodd6
# 1 science tctodd6
# 1 share tctodd6
# 1 shop tctodd6
# 1 soon tctodd6
# 1 sorry tctodd6
# 1 spend tctodd6
# 1 stubborn tctodd6
# 1 surprise tctodd6
# 1 take tctodd6
# 1 temper tctodd6
# 1 thank tctodd6
# 1 think tctodd6
# 1 tray tctodd6
# 1 us tctodd6
# 1 voluntary tctodd6
# 1 wait_notyet_ tctodd6
# 1 what tctodd6
# 1 when tctodd6
# 1 where tctodd6
# 1 which tctodd6
# 1 who tctodd6
# 1 why tctodd6
# 1 wild tctodd6
# 1 will tctodd6
# 1 write tctodd6
# 1 wrong tctodd6
# 1 yes tctodd6
# 1 you tctodd6
# 1 zero tctodd6
# 2 alive tctodd6
# 2 all tctodd6
# 2 answer tctodd6
# 2 boy tctodd6
# 2 building tctodd6
# 2 buy tctodd6
# 2 change_mind_ tctodd6
# 2 cold tctodd6
# 2 come tctodd6
# 2 computer_PC_ tctodd6
# 2 cost tctodd6
# 2 crazy tctodd6
# 2 danger tctodd6
# 2 deaf tctodd6
# 2 different tctodd6
# 2 draw tctodd6
# 2 drink tctodd6
# 2 eat tctodd6
# 2 exit tctodd6
# 2 flash tctodd6
# 2 forget tctodd6
# 2 girl tctodd6
# 2 give tctodd6
# 2 glove tctodd6
# 2 go tctodd6
# 2 God tctodd6
# 2 happy tctodd6
# 2 head tctodd6
# 2 hear tctodd6
# 2 hello tctodd6
# 2 his_hers tctodd6
# 2 hot tctodd6
# 2 how tctodd6
# 2 hurry tctodd6
# 2 hurt tctodd6
# 2 I tctodd6
# 2 innocent tctodd6
# 2 is_true_ tctodd6
# 2 joke tctodd6
# 2 juice tctodd6
# 2 know tctodd6
# 2 later tctodd6
# 2 lose tctodd6
# 2 love tctodd6
# 2 make tctodd6
# 2 man tctodd6
# 2 maybe tctodd6
# 2 mine tctodd6
# 2 money tctodd6
# 2 more tctodd6
# 2 name tctodd6
# 2 no tctodd6
# 2 Norway tctodd6
# 2 not tctodd6
# 2 paper tctodd6
# 2 pen tctodd6
# 2 please tctodd6
# 2 polite tctodd6
# 2 question tctodd6
# 2 read tctodd6
# 2 ready tctodd6
# 2 research tctodd6
# 2 responsible tctodd6
# 2 right tctodd6
# 2 sad tctodd6
# 2 same tctodd6
# 2 science tctodd6
# 2 share tctodd6
# 2 shop tctodd6
# 2 soon tctodd6
# 2 sorry tctodd6
# 2 spend tctodd6
# 2 stubborn tctodd6
# 2 surprise tctodd6
# 2 take tctodd6
# 2 temper tctodd6
# 2 thank tctodd6
# 2 think tctodd6
# 2 tray tctodd6
# 2 us tctodd6
# 2 voluntary tctodd6
# 2 wait_notyet_ tctodd6
# 2 what tctodd6
# 2 when tctodd6
# 2 where tctodd6
# 2 which tctodd6
# 2 who tctodd6
# 2 why tctodd6
# 2 wild tctodd6
# 2 will tctodd6
# 2 write tctodd6
# 2 wrong tctodd6
# 2 yes tctodd6
# 2 you tctodd6
# 2 zero tctodd6
# 3 alive tctodd6
# 3 all tctodd6
# 3 answer tctodd6
# 3 boy tctodd6
# 3 building tctodd6
# 3 buy tctodd6
# 3 change_mind_ tctodd6
# 3 cold tctodd6
# 3 come tctodd6
# 3 computer_PC_ tctodd6
# 3 cost tctodd6
# 3 crazy tctodd6
# 3 danger tctodd6
# 3 deaf tctodd6
# 3 different tctodd6
# 3 draw tctodd6
# 3 drink tctodd6
# 3 eat tctodd6
# 3 exit tctodd6
# 3 flash tctodd6
# 3 forget tctodd6
# 3 girl tctodd6
# 3 give tctodd6
# 3 glove tctodd6
# 3 go tctodd6
# 3 God tctodd6
# 3 happy tctodd6
# 3 head tctodd6
# 3 hear tctodd6
# 3 hello tctodd6
# 3 his_hers tctodd6
# 3 hot tctodd6
# 3 how tctodd6
# 3 hurry tctodd6
# 3 hurt tctodd6
# 3 I tctodd6
# 3 innocent tctodd6
# 3 is_true_ tctodd6
# 3 joke tctodd6
# 3 juice tctodd6
# 3 know tctodd6
# 3 later tctodd6
# 3 lose tctodd6
# 3 love tctodd6
# 3 make tctodd6
# 3 man tctodd6
# 3 maybe tctodd6
# 3 mine tctodd6
# 3 money tctodd6
# 3 more tctodd6
# 3 name tctodd6
# 3 no tctodd6
# 3 Norway tctodd6
# 3 not tctodd6
# 3 paper tctodd6
# 3 pen tctodd6
# 3 please tctodd6
# 3 polite tctodd6
# 3 question tctodd6
# 3 read tctodd6
# 3 ready tctodd6
# 3 research tctodd6
# 3 responsible tctodd6
# 3 right tctodd6
# 3 sad tctodd6
# 3 same tctodd6
# 3 science tctodd6
# 3 share tctodd6
# 3 shop tctodd6
# 3 soon tctodd6
# 3 sorry tctodd6
# 3 spend tctodd6
# 3 stubborn tctodd6
# 3 surprise tctodd6
# 3 take tctodd6
# 3 temper tctodd6
# 3 thank tctodd6
# 3 think tctodd6
# 3 tray tctodd6
# 3 us tctodd6
# 3 voluntary tctodd6
# 3 wait_notyet_ tctodd6
# 3 what tctodd6
# 3 when tctodd6
# 3 where tctodd6
# 3 which tctodd6
# 3 who tctodd6
# 3 why tctodd6
# 3 wild tctodd6
# 3 will tctodd6
# 3 write tctodd6
# 3 wrong tctodd6
# 3 yes tctodd6
# 3 you tctodd6
# 3 zero tctodd6
# 1 alive tctodd7
# 1 all tctodd7
# 1 answer tctodd7
# 1 boy tctodd7
# 1 building tctodd7
# 1 buy tctodd7
# 1 change_mind_ tctodd7
# 1 cold tctodd7
# 1 come tctodd7
# 1 computer_PC_ tctodd7
# 1 cost tctodd7
# 1 crazy tctodd7
# 1 danger tctodd7
# 1 deaf tctodd7
# 1 different tctodd7
# 1 draw tctodd7
# 1 drink tctodd7
# 1 eat tctodd7
# 1 exit tctodd7
# 1 flash tctodd7
# 1 forget tctodd7
# 1 girl tctodd7
# 1 give tctodd7
# 1 glove tctodd7
# 1 go tctodd7
# 1 God tctodd7
# 1 happy tctodd7
# 1 head tctodd7
# 1 hear tctodd7
# 1 hello tctodd7
# 1 his_hers tctodd7
# 1 hot tctodd7
# 1 how tctodd7
# 1 hurry tctodd7
# 1 hurt tctodd7
# 1 I tctodd7
# 1 innocent tctodd7
# 1 is_true_ tctodd7
# 1 joke tctodd7
# 1 juice tctodd7
# 1 know tctodd7
# 1 later tctodd7
# 1 lose tctodd7
# 1 love tctodd7
# 1 make tctodd7
# 1 man tctodd7
# 1 maybe tctodd7
# 1 mine tctodd7
# 1 money tctodd7
# 1 more tctodd7
# 1 name tctodd7
# 1 no tctodd7
# 1 Norway tctodd7
# 1 not tctodd7
# 1 paper tctodd7
# 1 pen tctodd7
# 1 please tctodd7
# 1 polite tctodd7
# 1 question tctodd7
# 1 read tctodd7
# 1 ready tctodd7
# 1 research tctodd7
# 1 responsible tctodd7
# 1 right tctodd7
# 1 sad tctodd7
# 1 same tctodd7
# 1 science tctodd7
# 1 share tctodd7
# 1 shop tctodd7
# 1 soon tctodd7
# 1 sorry tctodd7
# 1 spend tctodd7
# 1 stubborn tctodd7
# 1 surprise tctodd7
# 1 take tctodd7
# 1 temper tctodd7
# 1 thank tctodd7
# 1 think tctodd7
# 1 tray tctodd7
# 1 us tctodd7
# 1 voluntary tctodd7
# 1 wait_notyet_ tctodd7
# 1 what tctodd7
# 1 when tctodd7
# 1 where tctodd7
# 1 which tctodd7
# 1 who tctodd7
# 1 why tctodd7
# 1 wild tctodd7
# 1 will tctodd7
# 1 write tctodd7
# 1 wrong tctodd7
# 1 yes tctodd7
# 1 you tctodd7
# 1 zero tctodd7
# 2 alive tctodd7
# 2 all tctodd7
# 2 answer tctodd7
# 2 boy tctodd7
# 2 building tctodd7
# 2 buy tctodd7
# 2 change_mind_ tctodd7
# 2 cold tctodd7
# 2 come tctodd7
# 2 computer_PC_ tctodd7
# 2 cost tctodd7
# 2 crazy tctodd7
# 2 danger tctodd7
# 2 deaf tctodd7
# 2 different tctodd7
# 2 draw tctodd7
# 2 drink tctodd7
# 2 eat tctodd7
# 2 exit tctodd7
# 2 flash tctodd7
# 2 forget tctodd7
# 2 girl tctodd7
# 2 give tctodd7
# 2 glove tctodd7
# 2 go tctodd7
# 2 God tctodd7
# 2 happy tctodd7
# 2 head tctodd7
# 2 hear tctodd7
# 2 hello tctodd7
# 2 his_hers tctodd7
# 2 hot tctodd7
# 2 how tctodd7
# 2 hurry tctodd7
# 2 hurt tctodd7
# 2 I tctodd7
# 2 innocent tctodd7
# 2 is_true_ tctodd7
# 2 joke tctodd7
# 2 juice tctodd7
# 2 know tctodd7
# 2 later tctodd7
# 2 lose tctodd7
# 2 love tctodd7
# 2 make tctodd7
# 2 man tctodd7
# 2 maybe tctodd7
# 2 mine tctodd7
# 2 money tctodd7
# 2 more tctodd7
# 2 name tctodd7
# 2 no tctodd7
# 2 Norway tctodd7
# 2 not tctodd7
# 2 paper tctodd7
# 2 pen tctodd7
# 2 please tctodd7
# 2 polite tctodd7
# 2 question tctodd7
# 2 read tctodd7
# 2 ready tctodd7
# 2 research tctodd7
# 2 responsible tctodd7
# 2 right tctodd7
# 2 sad tctodd7
# 2 same tctodd7
# 2 science tctodd7
# 2 share tctodd7
# 2 shop tctodd7
# 2 soon tctodd7
# 2 sorry tctodd7
# 2 spend tctodd7
# 2 stubborn tctodd7
# 2 surprise tctodd7
# 2 take tctodd7
# 2 temper tctodd7
# 2 thank tctodd7
# 2 think tctodd7
# 2 tray tctodd7
# 2 us tctodd7
# 2 voluntary tctodd7
# 2 wait_notyet_ tctodd7
# 2 what tctodd7
# 2 when tctodd7
# 2 where tctodd7
# 2 which tctodd7
# 2 who tctodd7
# 2 why tctodd7
# 2 wild tctodd7
# 2 will tctodd7
# 2 write tctodd7
# 2 wrong tctodd7
# 2 yes tctodd7
# 2 you tctodd7
# 2 zero tctodd7
# 3 alive tctodd7
# 3 all tctodd7
# 3 answer tctodd7
# 3 boy tctodd7
# 3 building tctodd7
# 3 buy tctodd7
# 3 change_mind_ tctodd7
# 3 cold tctodd7
# 3 come tctodd7
# 3 computer_PC_ tctodd7
# 3 cost tctodd7
# 3 crazy tctodd7
# 3 danger tctodd7
# 3 deaf tctodd7
# 3 different tctodd7
# 3 draw tctodd7
# 3 drink tctodd7
# 3 eat tctodd7
# 3 exit tctodd7
# 3 flash tctodd7
# 3 forget tctodd7
# 3 girl tctodd7
# 3 give tctodd7
# 3 glove tctodd7
# 3 go tctodd7
# 3 God tctodd7
# 3 happy tctodd7
# 3 head tctodd7
# 3 hear tctodd7
# 3 hello tctodd7
# 3 his_hers tctodd7
# 3 hot tctodd7
# 3 how tctodd7
# 3 hurry tctodd7
# 3 hurt tctodd7
# 3 I tctodd7
# 3 innocent tctodd7
# 3 is_true_ tctodd7
# 3 joke tctodd7
# 3 juice tctodd7
# 3 know tctodd7
# 3 later tctodd7
# 3 lose tctodd7
# 3 love tctodd7
# 3 make tctodd7
# 3 man tctodd7
# 3 maybe tctodd7
# 3 mine tctodd7
# 3 money tctodd7
# 3 more tctodd7
# 3 name tctodd7
# 3 no tctodd7
# 3 Norway tctodd7
# 3 not tctodd7
# 3 paper tctodd7
# 3 pen tctodd7
# 3 please tctodd7
# 3 polite tctodd7
# 3 question tctodd7
# 3 read tctodd7
# 3 ready tctodd7
# 3 research tctodd7
# 3 responsible tctodd7
# 3 right tctodd7
# 3 sad tctodd7
# 3 same tctodd7
# 3 science tctodd7
# 3 share tctodd7
# 3 shop tctodd7
# 3 soon tctodd7
# 3 sorry tctodd7
# 3 spend tctodd7
# 3 stubborn tctodd7
# 3 surprise tctodd7
# 3 take tctodd7
# 3 temper tctodd7
# 3 thank tctodd7
# 3 think tctodd7
# 3 tray tctodd7
# 3 us tctodd7
# 3 voluntary tctodd7
# 3 wait_notyet_ tctodd7
# 3 what tctodd7
# 3 when tctodd7
# 3 where tctodd7
# 3 which tctodd7
# 3 who tctodd7
# 3 why tctodd7
# 3 wild tctodd7
# 3 will tctodd7
# 3 write tctodd7
# 3 wrong tctodd7
# 3 yes tctodd7
# 3 you tctodd7
# 3 zero tctodd7
# 1 alive tctodd8
# 1 all tctodd8
# 1 answer tctodd8
# 1 boy tctodd8
# 1 building tctodd8
# 1 buy tctodd8
# 1 change_mind_ tctodd8
# 1 cold tctodd8
# 1 come tctodd8
# 1 computer_PC_ tctodd8
# 1 cost tctodd8
# 1 crazy tctodd8
# 1 danger tctodd8
# 1 deaf tctodd8
# 1 different tctodd8
# 1 draw tctodd8
# 1 drink tctodd8
# 1 eat tctodd8
# 1 exit tctodd8
# 1 flash tctodd8
# 1 forget tctodd8
# 1 girl tctodd8
# 1 give tctodd8
# 1 glove tctodd8
# 1 go tctodd8
# 1 God tctodd8
# 1 happy tctodd8
# 1 head tctodd8
# 1 hear tctodd8
# 1 hello tctodd8
# 1 his_hers tctodd8
# 1 hot tctodd8
# 1 how tctodd8
# 1 hurry tctodd8
# 1 hurt tctodd8
# 1 I tctodd8
# 1 innocent tctodd8
# 1 is_true_ tctodd8
# 1 joke tctodd8
# 1 juice tctodd8
# 1 know tctodd8
# 1 later tctodd8
# 1 lose tctodd8
# 1 love tctodd8
# 1 make tctodd8
# 1 man tctodd8
# 1 maybe tctodd8
# 1 mine tctodd8
# 1 money tctodd8
# 1 more tctodd8
# 1 name tctodd8
# 1 no tctodd8
# 1 Norway tctodd8
# 1 not tctodd8
# 1 paper tctodd8
# 1 pen tctodd8
# 1 please tctodd8
# 1 polite tctodd8
# 1 question tctodd8
# 1 read tctodd8
# 1 ready tctodd8
# 1 research tctodd8
# 1 responsible tctodd8
# 1 right tctodd8
# 1 sad tctodd8
# 1 same tctodd8
# 1 science tctodd8
# 1 share tctodd8
# 1 shop tctodd8
# 1 soon tctodd8
# 1 sorry tctodd8
# 1 spend tctodd8
# 1 stubborn tctodd8
# 1 surprise tctodd8
# 1 take tctodd8
# 1 temper tctodd8
# 1 thank tctodd8
# 1 think tctodd8
# 1 tray tctodd8
# 1 us tctodd8
# 1 voluntary tctodd8
# 1 wait_notyet_ tctodd8
# 1 what tctodd8
# 1 when tctodd8
# 1 where tctodd8
# 1 which tctodd8
# 1 who tctodd8
# 1 why tctodd8
# 1 wild tctodd8
# 1 will tctodd8
# 1 write tctodd8
# 1 wrong tctodd8
# 1 yes tctodd8
# 1 you tctodd8
# 1 zero tctodd8
# 2 alive tctodd8
# 2 all tctodd8
# 2 answer tctodd8
# 2 boy tctodd8
# 2 building tctodd8
# 2 buy tctodd8
# 2 change_mind_ tctodd8
# 2 cold tctodd8
# 2 come tctodd8
# 2 computer_PC_ tctodd8
# 2 cost tctodd8
# 2 crazy tctodd8
# 2 danger tctodd8
# 2 deaf tctodd8
# 2 different tctodd8
# 2 draw tctodd8
# 2 drink tctodd8
# 2 eat tctodd8
# 2 exit tctodd8
# 2 flash tctodd8
# 2 forget tctodd8
# 2 girl tctodd8
# 2 give tctodd8
# 2 glove tctodd8
# 2 go tctodd8
# 2 God tctodd8
# 2 happy tctodd8
# 2 head tctodd8
# 2 hear tctodd8
# 2 hello tctodd8
# 2 his_hers tctodd8
# 2 hot tctodd8
# 2 how tctodd8
# 2 hurry tctodd8
# 2 hurt tctodd8
# 2 I tctodd8
# 2 innocent tctodd8
# 2 is_true_ tctodd8
# 2 joke tctodd8
# 2 juice tctodd8
# 2 know tctodd8
# 2 later tctodd8
# 2 lose tctodd8
# 2 love tctodd8
# 2 make tctodd8
# 2 man tctodd8
# 2 maybe tctodd8
# 2 mine tctodd8
# 2 money tctodd8
# 2 more tctodd8
# 2 name tctodd8
# 2 no tctodd8
# 2 Norway tctodd8
# 2 not tctodd8
# 2 paper tctodd8
# 2 pen tctodd8
# 2 please tctodd8
# 2 polite tctodd8
# 2 question tctodd8
# 2 read tctodd8
# 2 ready tctodd8
# 2 research tctodd8
# 2 responsible tctodd8
# 2 right tctodd8
# 2 sad tctodd8
# 2 same tctodd8
# 2 science tctodd8
# 2 share tctodd8
# 2 shop tctodd8
# 2 soon tctodd8
# 2 sorry tctodd8
# 2 spend tctodd8
# 2 stubborn tctodd8
# 2 surprise tctodd8
# 2 take tctodd8
# 2 temper tctodd8
# 2 thank tctodd8
# 2 think tctodd8
# 2 tray tctodd8
# 2 us tctodd8
# 2 voluntary tctodd8
# 2 wait_notyet_ tctodd8
# 2 what tctodd8
# 2 when tctodd8
# 2 where tctodd8
# 2 which tctodd8
# 2 who tctodd8
# 2 why tctodd8
# 2 wild tctodd8
# 2 will tctodd8
# 2 write tctodd8
# 2 wrong tctodd8
# 2 yes tctodd8
# 2 you tctodd8
# 2 zero tctodd8
# 3 alive tctodd8
# 3 all tctodd8
# 3 answer tctodd8
# 3 boy tctodd8
# 3 building tctodd8
# 3 buy tctodd8
# 3 change_mind_ tctodd8
# 3 cold tctodd8
# 3 come tctodd8
# 3 computer_PC_ tctodd8
# 3 cost tctodd8
# 3 crazy tctodd8
# 3 danger tctodd8
# 3 deaf tctodd8
# 3 different tctodd8
# 3 draw tctodd8
# 3 drink tctodd8
# 3 eat tctodd8
# 3 exit tctodd8
# 3 flash tctodd8
# 3 forget tctodd8
# 3 girl tctodd8
# 3 give tctodd8
# 3 glove tctodd8
# 3 go tctodd8
# 3 God tctodd8
# 3 happy tctodd8
# 3 head tctodd8
# 3 hear tctodd8
# 3 hello tctodd8
# 3 his_hers tctodd8
# 3 hot tctodd8
# 3 how tctodd8
# 3 hurry tctodd8
# 3 hurt tctodd8
# 3 I tctodd8
# 3 innocent tctodd8
# 3 is_true_ tctodd8
# 3 joke tctodd8
# 3 juice tctodd8
# 3 know tctodd8
# 3 later tctodd8
# 3 lose tctodd8
# 3 love tctodd8
# 3 make tctodd8
# 3 man tctodd8
# 3 maybe tctodd8
# 3 mine tctodd8
# 3 money tctodd8
# 3 more tctodd8
# 3 name tctodd8
# 3 no tctodd8
# 3 Norway tctodd8
# 3 not tctodd8
# 3 paper tctodd8
# 3 pen tctodd8
# 3 please tctodd8
# 3 polite tctodd8
# 3 question tctodd8
# 3 read tctodd8
# 3 ready tctodd8
# 3 research tctodd8
# 3 responsible tctodd8
# 3 right tctodd8
# 3 sad tctodd8
# 3 same tctodd8
# 3 science tctodd8
# 3 share tctodd8
# 3 shop tctodd8
# 3 soon tctodd8
# 3 sorry tctodd8
# 3 spend tctodd8
# 3 stubborn tctodd8
# 3 surprise tctodd8
# 3 take tctodd8
# 3 temper tctodd8
# 3 thank tctodd8
# 3 think tctodd8
# 3 tray tctodd8
# 3 us tctodd8
# 3 voluntary tctodd8
# 3 wait_notyet_ tctodd8
# 3 what tctodd8
# 3 when tctodd8
# 3 where tctodd8
# 3 which tctodd8
# 3 who tctodd8
# 3 why tctodd8
# 3 wild tctodd8
# 3 will tctodd8
# 3 write tctodd8
# 3 wrong tctodd8
# 3 yes tctodd8
# 3 you tctodd8
# 3 zero tctodd8
# 1 alive tctodd9
# 1 all tctodd9
# 1 answer tctodd9
# 1 boy tctodd9
# 1 building tctodd9
# 1 buy tctodd9
# 1 change_mind_ tctodd9
# 1 cold tctodd9
# 1 come tctodd9
# 1 computer_PC_ tctodd9
# 1 cost tctodd9
# 1 crazy tctodd9
# 1 danger tctodd9
# 1 deaf tctodd9
# 1 different tctodd9
# 1 draw tctodd9
# 1 drink tctodd9
# 1 eat tctodd9
# 1 exit tctodd9
# 1 flash tctodd9
# 1 forget tctodd9
# 1 girl tctodd9
# 1 give tctodd9
# 1 glove tctodd9
# 1 go tctodd9
# 1 God tctodd9
# 1 happy tctodd9
# 1 head tctodd9
# 1 hear tctodd9
# 1 hello tctodd9
# 1 his_hers tctodd9
# 1 hot tctodd9
# 1 how tctodd9
# 1 hurry tctodd9
# 1 hurt tctodd9
# 1 I tctodd9
# 1 innocent tctodd9
# 1 is_true_ tctodd9
# 1 joke tctodd9
# 1 juice tctodd9
# 1 know tctodd9
# 1 later tctodd9
# 1 lose tctodd9
# 1 love tctodd9
# 1 make tctodd9
# 1 man tctodd9
# 1 maybe tctodd9
# 1 mine tctodd9
# 1 money tctodd9
# 1 more tctodd9
# 1 name tctodd9
# 1 no tctodd9
# 1 Norway tctodd9
# 1 not tctodd9
# 1 paper tctodd9
# 1 pen tctodd9
# 1 please tctodd9
# 1 polite tctodd9
# 1 question tctodd9
# 1 read tctodd9
# 1 ready tctodd9
# 1 research tctodd9
# 1 responsible tctodd9
# 1 right tctodd9
# 1 sad tctodd9
# 1 same tctodd9
# 1 science tctodd9
# 1 share tctodd9
# 1 shop tctodd9
# 1 soon tctodd9
# 1 sorry tctodd9
# 1 spend tctodd9
# 1 stubborn tctodd9
# 1 surprise tctodd9
# 1 take tctodd9
# 1 temper tctodd9
# 1 thank tctodd9
# 1 think tctodd9
# 1 tray tctodd9
# 1 us tctodd9
# 1 voluntary tctodd9
# 1 wait_notyet_ tctodd9
# 1 what tctodd9
# 1 when tctodd9
# 1 where tctodd9
# 1 which tctodd9
# 1 who tctodd9
# 1 why tctodd9
# 1 wild tctodd9
# 1 will tctodd9
# 1 write tctodd9
# 1 wrong tctodd9
# 1 yes tctodd9
# 1 you tctodd9
# 1 zero tctodd9
# 2 alive tctodd9
# 2 all tctodd9
# 2 answer tctodd9
# 2 boy tctodd9
# 2 building tctodd9
# 2 buy tctodd9
# 2 change_mind_ tctodd9
# 2 cold tctodd9
# 2 come tctodd9
# 2 computer_PC_ tctodd9
# 2 cost tctodd9
# 2 crazy tctodd9
# 2 danger tctodd9
# 2 deaf tctodd9
# 2 different tctodd9
# 2 draw tctodd9
# 2 drink tctodd9
# 2 eat tctodd9
# 2 exit tctodd9
# 2 flash tctodd9
# 2 forget tctodd9
# 2 girl tctodd9
# 2 give tctodd9
# 2 glove tctodd9
# 2 go tctodd9
# 2 God tctodd9
# 2 happy tctodd9
# 2 head tctodd9
# 2 hear tctodd9
# 2 hello tctodd9
# 2 his_hers tctodd9
# 2 hot tctodd9
# 2 how tctodd9
# 2 hurry tctodd9
# 2 hurt tctodd9
# 2 I tctodd9
# 2 innocent tctodd9
# 2 is_true_ tctodd9
# 2 joke tctodd9
# 2 juice tctodd9
# 2 know tctodd9
# 2 later tctodd9
# 2 lose tctodd9
# 2 love tctodd9
# 2 make tctodd9
# 2 man tctodd9
# 2 maybe tctodd9
# 2 mine tctodd9
# 2 money tctodd9
# 2 more tctodd9
# 2 name tctodd9
# 2 no tctodd9
# 2 Norway tctodd9
# 2 not tctodd9
# 2 paper tctodd9
# 2 pen tctodd9
# 2 please tctodd9
# 2 polite tctodd9
# 2 question tctodd9
# 2 read tctodd9
# 2 ready tctodd9
# 2 research tctodd9
# 2 responsible tctodd9
# 2 right tctodd9
# 2 sad tctodd9
# 2 same tctodd9
# 2 science tctodd9
# 2 share tctodd9
# 2 shop tctodd9
# 2 soon tctodd9
# 2 sorry tctodd9
# 2 spend tctodd9
# 2 stubborn tctodd9
# 2 surprise tctodd9
# 2 take tctodd9
# 2 temper tctodd9
# 2 thank tctodd9
# 2 think tctodd9
# 2 tray tctodd9
# 2 us tctodd9
# 2 voluntary tctodd9
# 2 wait_notyet_ tctodd9
# 2 what tctodd9
# 2 when tctodd9
# 2 where tctodd9
# 2 which tctodd9
# 2 who tctodd9
# 2 why tctodd9
# 2 wild tctodd9
# 2 will tctodd9
# 2 write tctodd9
# 2 wrong tctodd9
# 2 yes tctodd9
# 2 you tctodd9
# 2 zero tctodd9
# 3 alive tctodd9
# 3 all tctodd9
# 3 answer tctodd9
# 3 boy tctodd9
# 3 building tctodd9
# 3 buy tctodd9
# 3 change_mind_ tctodd9
# 3 cold tctodd9
# 3 come tctodd9
# 3 computer_PC_ tctodd9
# 3 cost tctodd9
# 3 crazy tctodd9
# 3 danger tctodd9
# 3 deaf tctodd9
# 3 different tctodd9
# 3 draw tctodd9
# 3 drink tctodd9
# 3 eat tctodd9
# 3 exit tctodd9
# 3 flash tctodd9
# 3 forget tctodd9
# 3 girl tctodd9
# 3 give tctodd9
# 3 glove tctodd9
# 3 go tctodd9
# 3 God tctodd9
# 3 happy tctodd9
# 3 head tctodd9
# 3 hear tctodd9
# 3 hello tctodd9
# 3 his_hers tctodd9
# 3 hot tctodd9
# 3 how tctodd9
# 3 hurry tctodd9
# 3 hurt tctodd9
# 3 I tctodd9
# 3 innocent tctodd9
# 3 is_true_ tctodd9
# 3 joke tctodd9
# 3 juice tctodd9
# 3 know tctodd9
# 3 later tctodd9
# 3 lose tctodd9
# 3 love tctodd9
# 3 make tctodd9
# 3 man tctodd9
# 3 maybe tctodd9
# 3 mine tctodd9
# 3 money tctodd9
# 3 more tctodd9
# 3 name tctodd9
# 3 no tctodd9
# 3 Norway tctodd9
# 3 not tctodd9
# 3 paper tctodd9
# 3 pen tctodd9
# 3 please tctodd9
# 3 polite tctodd9
# 3 question tctodd9
# 3 read tctodd9
# 3 ready tctodd9
# 3 research tctodd9
# 3 responsible tctodd9
# 3 right tctodd9
# 3 sad tctodd9
# 3 same tctodd9
# 3 science tctodd9
# 3 share tctodd9
# 3 shop tctodd9
# 3 soon tctodd9
# 3 sorry tctodd9
# 3 spend tctodd9
# 3 stubborn tctodd9
# 3 surprise tctodd9
# 3 take tctodd9
# 3 temper tctodd9
# 3 thank tctodd9
# 3 think tctodd9
# 3 tray tctodd9
# 3 us tctodd9
# 3 voluntary tctodd9
# 3 wait_notyet_ tctodd9
# 3 what tctodd9
# 3 when tctodd9
# 3 where tctodd9
# 3 which tctodd9
# 3 who tctodd9
# 3 why tctodd9
# 3 wild tctodd9
# 3 will tctodd9
# 3 write tctodd9
# 3 wrong tctodd9
# 3 yes tctodd9
# 3 you tctodd9
# 3 zero tctodd9

# %%
X = signs_flat[signs_flat.columns[2:]]
del X['label']
Y = signs_flat['label']
le = LabelEncoder()
le.fit(Y)
Y = le.transform(Y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, random_state=42)

lin_clf = LinearSVC()
lin_clf.fit(X_train, y_train)
# Out:
# LinearSVC(C=1.0, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='squared_hinge', max_iter=1000,
#      multi_class='ovr', penalty='l2', random_state=None, tol=0.0001,
#      verbose=0)

# %%
Predicted = lin_clf.predict(X_test)

# %%
sum(Predicted == y_test)/len(Y)
# Out:
# 0.19086651053864168

# %%
signs_new = temporal_scale(signs)

# %%
len(signs_new)
# Out:
# 16245

# %%
len(labels)
# Out:
# 95

# %%
len(signs_all)
# Out:
# 146949

# %%
len(signs_all_ts)
# Out:
# 146205

# %%
t
